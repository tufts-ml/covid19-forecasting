# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import tensorflow as tf

import sys
sys.path.append('/mnt/c/Users/kheut/code/covid19-forecasting/tf_model_1p5/')

from enum import Enum

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense

import tensorflow_probability as tfp
from scipy.stats import beta, truncnorm


# Local imports from model.py, data.py
from model import CovidModel, LogPoissonProb, get_logging_callbacks, Comp, Vax
from model_config import ModelConfig, ModelVar, replace_keys
from data import read_data, create_warmup
#from plots import make_all_plots

import scipy
import copy

import matplotlib
import matplotlib.pyplot as plt

import json

plt.rcParams.update({'font.size': 20}) # set plot font sizes
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
old_config_path = '/mnt/c/Users/kheut/code/covid19-forecasting/tf_model_1p5/model_config.json'
new_config_path = '/mnt/c/Users/kheut/code/covid19-forecasting/tf_model_1p5/model_config_new_format.json'

# %%
with open(old_config_path, 'r') as f:
    old_config_json = json.load(f)

# %%
new_config_json = {}

var_transforms = [
    ('T_serial', 'softplus'),
    ('delta', 'sigmoid'),
    ('epsilon', 'sigmoid'),
]

for this_var, this_transform in var_transforms:
    new_config_json[this_var] = copy.deepcopy(old_config_json[this_var])
    
    parsed_transform = ModelVar._parse_transform(this_transform)
    
    for part in new_config_json[this_var].keys():
        if part =='prior':
            continue
        for param in new_config_json[this_var][part].keys():
            new_config_json[this_var][part][param] = parsed_transform.inverse(
                tf.cast(
                    new_config_json[this_var][part][param],
                tf.float32)
            ).numpy()

    new_config_json[this_var]['mean_transform']=this_transform
    
var_transforms = [
    ('rho', 'sigmoid'),
    ('eff', 'sigmoid'),
    ('lambda', 'softplus'),
    ('nu', 'softplus'),
    ('warmup', 'scale_100_softplus'),
    ('init_count', 'scale_100_softplus'),
]

for this_var, this_transform in var_transforms:
    new_config_json[this_var] = copy.deepcopy(old_config_json[this_var])
    
    parsed_transform = ModelVar._parse_transform(this_transform)
    
    for compartment in new_config_json[this_var].keys():
        for part in new_config_json[this_var][compartment].keys():
            if part =='prior':
                continue
            for vax in new_config_json[this_var][compartment][part].keys():
                for param in new_config_json[this_var][compartment][part][vax].keys():
                    if param != 'slope':
                        new_config_json[this_var][compartment][part][vax][param] = parsed_transform.inverse(
                            tf.cast(
                                new_config_json[this_var][compartment][part][vax][param],
                            tf.float32)
                        ).numpy()

    new_config_json[this_var]['mean_transform']=this_transform
    
new_config_json = replace_keys(new_config_json, str, from_tensor=True)

# %%
old_config_json
# Out:
# {'T_serial': {'prior': {'loc': 5.8, 'scale': 1},
#   'value': {'loc': 5.3, 'scale': 1}},
#  'delta': {'prior': {'a': 1, 'b': 1}, 'value': {'loc': 0.03, 'scale': 0.2}},
#  'epsilon': {'prior': {'a': 1, 'b': 1}, 'value': {'loc': 0.2, 'scale': 0.3}},
#  'rho': {'M': {'prior': {'0': {'a': 4.5, 'b': 3.1}},
#    'value': {'0': {'loc': 0.35, 'scale': 0.1}}},
#   'G': {'prior': {'0': {'a': 1.1, 'b': 9.6}},
#    'value': {'0': {'loc': 0.12, 'scale': 0.1}}},
#   'I': {'prior': {'0': {'a': 1.1, 'b': 9.6}},
#    'value': {'0': {'loc': 0.12, 'scale': 0.1}}},
#   'D': {'prior': {'0': {'a': 1.1, 'b': 9.6}},
#    'value': {'0': {'loc': 0.12, 'scale': 0.1}}}},
#  'eff': {'M': {'prior': {'1': {'a': 1, 'b': 1}},
#    'value': {'1': {'loc': 0.5, 'scale': 0.1}}},
#   'G': {'prior': {'1': {'a': 1, 'b': 1}},
#    'value': {'1': {'loc': 0.5, 'scale': 0.1}}},
#   'I': {'prior': {'1': {'a': 1, 'b': 1}},
#    'value': {'1': {'loc': 0.5, 'scale': 0.1}}},
#   'D': {'prior': {'1': {'a': 1, 'b': 1}},
#    'value': {'1': {'loc': 0.5, 'scale': 0.1}}}},
#  'lambda': {'M': {'prior': {'0': {'loc': 4.7, 'scale': 1},
#     '1': {'loc': 4.7, 'scale': 1}},
#    'value': {'0': {'loc': 3, 'scale': 1}, '1': {'loc': 3, 'scale': 1}}},
#   'G': {'prior': {'0': {'loc': 3.3, 'scale': 1},
#     '1': {'loc': 3.3, 'scale': 1}},
#    'value': {'0': {'loc': 3.3, 'scale': 1}, '1': {'loc': 3.3, 'scale': 1}}},
#   'I': {'prior': {'0': {'loc': 3.3, 'scale': 1},
#     '1': {'loc': 3.3, 'scale': 1}},
#    'value': {'0': {'loc': 3.3, 'scale': 1}, '1': {'loc': 3.3, 'scale': 1}}},
#   'I_bar': {'prior': {'0': {'loc': 3.3, 'scale': 1},
#     '1': {'loc': 3.3, 'scale': 1}},
#    'value': {'0': {'loc': 3.3, 'scale': 1}, '1': {'loc': 3.3, 'scale': 1}}},
#   'D': {'prior': {'0': {'loc': 3.3, 'scale': 1},
#     '1': {'loc': 3.3, 'scale': 1}},
#    'value': {'0': {'loc': 3.3, 'scale': 1}, '1': {'loc': 3.3, 'scale': 1}}},
#   'D_bar': {'prior': {'0': {'loc': 3.3, 'scale': 1},
#     '1': {'loc': 3.3, 'scale': 1}},
#    'value': {'0': {'loc': 3.3, 'scale': 1}, '1': {'loc': 3.3, 'scale': 1}}}},
#  'nu': {'M': {'prior': {'0': {'loc': 3.1, 'scale': 1.2},
#     '1': {'loc': 3.1, 'scale': 1.2}},
#    'value': {'0': {'loc': 5, 'scale': 1.2}, '1': {'loc': 5, 'scale': 1.2}}},
#   'G': {'prior': {'0': {'loc': 9, 'scale': 3}, '1': {'loc': 9, 'scale': 3}},
#    'value': {'0': {'loc': 9, 'scale': 0.2}, '1': {'loc': 9, 'scale': 0.2}}},
#   'I': {'prior': {'0': {'loc': 9, 'scale': 3}, '1': {'loc': 9, 'scale': 3}},
#    'value': {'0': {'loc': 9, 'scale': 0.2}, '1': {'loc': 9, 'scale': 0.2}}},
#   'I_bar': {'prior': {'0': {'loc': 9, 'scale': 3},
#     '1': {'loc': 9, 'scale': 3}},
#    'value': {'0': {'loc': 9, 'scale': 0.2}, '1': {'loc': 9, 'scale': 0.2}}},
#   'D': {'prior': {'0': {'loc': 9, 'scale': 3}, '1': {'loc': 9, 'scale': 3}},
#    'value': {'0': {'loc': 9, 'scale': 0.2}, '1': {'loc': 9, 'scale': 0.2}}},
#   'D_bar': {'prior': {'0': {'loc': 9, 'scale': 3},
#     '1': {'loc': 9, 'scale': 3}},
#    'value': {'0': {'loc': 9, 'scale': 0.2}, '1': {'loc': 9, 'scale': 0.2}}}},
#  'warmup': {'A': {'prior': {'0': {'slope': 0, 'intercept': 850, 'scale': 85},
#     '1': {'slope': 0, 'intercept': 380, 'scale': 38}},
#    'value': {'0': {'slope': 0, 'intercept': 850, 'scale': 85},
#     '1': {'slope': 0, 'intercept': 380, 'scale': 38}}},
#   'M': {'prior': {'0': {'slope': 0, 'intercept': 650, 'scale': 65},
#     '1': {'slope': 0, 'intercept': 300, 'scale': 30}},
#    'value': {'0': {'slope': 0, 'intercept': 650, 'scale': 65},
#     '1': {'slope': 0, 'intercept': 300, 'scale': 30}}},
#   'G': {'prior': {'0': {'slope': 0, 'intercept': 30, 'scale': 10},
#     '1': {'slope': 0, 'intercept': 10, 'scale': 5}},
#    'value': {'0': {'slope': 0, 'intercept': 30, 'scale': 10},
#     '1': {'slope': 0, 'intercept': 10, 'scale': 5}}},
#   'GR': {'prior': {'0': {'slope': 0, 'intercept': 20, 'scale': 10},
#     '1': {'slope': 0, 'intercept': 10, 'scale': 5}},
#    'value': {'0': {'slope': 0, 'intercept': 20, 'scale': 10},
#     '1': {'slope': 0, 'intercept': 10, 'scale': 5}}},
#   'I': {'prior': {'0': {'slope': 0, 'intercept': 10, 'scale': 5},
#     '1': {'slope': 0, 'intercept': 5, 'scale': 3}},
#    'value': {'0': {'slope': 0, 'intercept': 10, 'scale': 5},
#     '1': {'slope': 0, 'intercept': 5, 'scale': 3}}},
#   'IR': {'prior': {'0': {'slope': 0, 'intercept': 5, 'scale': 5},
#     '1': {'slope': 0, 'intercept': 3, 'scale': 2}},
#    'value': {'0': {'slope': 0, 'intercept': 5, 'scale': 5},
#     '1': {'slope': 0, 'intercept': 3, 'scale': 2}}}},
#  'init_count': {'G': {'prior': {'0': {'loc': 320, 'scale': 32},
#     '1': {'loc': 180, 'scale': 18}},
#    'value': {'0': {'loc': 320, 'scale': 32}, '1': {'loc': 180, 'scale': 18}}},
#   'I': {'prior': {'0': {'loc': 140, 'scale': 20},
#     '1': {'loc': 10, 'scale': 5}},
#    'value': {'0': {'loc': 140, 'scale': 20}, '1': {'loc': 10, 'scale': 5}}}}}

# %%
new_config_json
# Out:
# {'T_serial': {'prior': {'loc': '5.8', 'scale': '1'},
#   'value': {'loc': '5.2949963', 'scale': '0.54132485'},
#   'mean_transform': 'softplus'},
#  'delta': {'prior': {'a': '1', 'b': '1'},
#   'value': {'loc': '-3.4760988', 'scale': '-1.3862944'},
#   'mean_transform': 'sigmoid'},
#  'epsilon': {'prior': {'a': '1', 'b': '1'},
#   'value': {'loc': '-1.3862944', 'scale': '-0.84729785'},
#   'mean_transform': 'sigmoid'},
#  'rho': {'M': {'prior': {0: {'a': '4.5', 'b': '3.1'}},
#    'value': {0: {'loc': '-0.6190392', 'scale': '-2.1972246'}}},
#   'G': {'prior': {0: {'a': '1.1', 'b': '9.6'}},
#    'value': {0: {'loc': '-1.9924302', 'scale': '-2.1972246'}}},
#   'I': {'prior': {0: {'a': '1.1', 'b': '9.6'}},
#    'value': {0: {'loc': '-1.9924302', 'scale': '-2.1972246'}}},
#   'D': {'prior': {0: {'a': '1.1', 'b': '9.6'}},
#    'value': {0: {'loc': '-1.9924302', 'scale': '-2.1972246'}}},
#   'mean_transform': 'sigmoid'},
#  'eff': {'M': {'prior': {1: {'a': '1', 'b': '1'}},
#    'value': {1: {'loc': '0.0', 'scale': '-2.1972246'}}},
#   'G': {'prior': {1: {'a': '1', 'b': '1'}},
#    'value': {1: {'loc': '0.0', 'scale': '-2.1972246'}}},
#   'I': {'prior': {1: {'a': '1', 'b': '1'}},
#    'value': {1: {'loc': '0.0', 'scale': '-2.1972246'}}},
#   'D': {'prior': {1: {'a': '1', 'b': '1'}},
#    'value': {1: {'loc': '0.0', 'scale': '-2.1972246'}}},
#   'mean_transform': 'sigmoid'},
#  'lambda': {'M': {'prior': {0: {'loc': '4.7', 'scale': '1'},
#     1: {'loc': '4.7', 'scale': '1'}},
#    'value': {0: {'loc': '2.9489307', 'scale': '0.54132485'},
#     1: {'loc': '2.9489307', 'scale': '0.54132485'}}},
#   'G': {'prior': {0: {'loc': '3.3', 'scale': '1'},
#     1: {'loc': '3.3', 'scale': '1'}},
#    'value': {0: {'loc': '3.2624195', 'scale': '0.54132485'},
#     1: {'loc': '3.2624195', 'scale': '0.54132485'}}},
#   'I': {'prior': {0: {'loc': '3.3', 'scale': '1'},
#     1: {'loc': '3.3', 'scale': '1'}},
#    'value': {0: {'loc': '3.2624195', 'scale': '0.54132485'},
#     1: {'loc': '3.2624195', 'scale': '0.54132485'}}},
#   'I_bar': {'prior': {0: {'loc': '3.3', 'scale': '1'},
#     1: {'loc': '3.3', 'scale': '1'}},
#    'value': {0: {'loc': '3.2624195', 'scale': '0.54132485'},
#     1: {'loc': '3.2624195', 'scale': '0.54132485'}}},
#   'D': {'prior': {0: {'loc': '3.3', 'scale': '1'},
#     1: {'loc': '3.3', 'scale': '1'}},
#    'value': {0: {'loc': '3.2624195', 'scale': '0.54132485'},
#     1: {'loc': '3.2624195', 'scale': '0.54132485'}}},
#   'D_bar': {'prior': {0: {'loc': '3.3', 'scale': '1'},
#     1: {'loc': '3.3', 'scale': '1'}},
#    'value': {0: {'loc': '3.2624195', 'scale': '0.54132485'},
#     1: {'loc': '3.2624195', 'scale': '0.54132485'}}},
#   'mean_transform': 'softplus'},
#  'nu': {'M': {'prior': {0: {'loc': '3.1', 'scale': '1.2'},
#     1: {'loc': '3.1', 'scale': '1.2'}},
#    'value': {0: {'loc': '4.9932394', 'scale': '0.8416177'},
#     1: {'loc': '4.9932394', 'scale': '0.8416177'}}},
#   'G': {'prior': {0: {'loc': '9', 'scale': '3'},
#     1: {'loc': '9', 'scale': '3'}},
#    'value': {0: {'loc': '8.999877', 'scale': '-1.5077717'},
#     1: {'loc': '8.999877', 'scale': '-1.5077717'}}},
#   'I': {'prior': {0: {'loc': '9', 'scale': '3'},
#     1: {'loc': '9', 'scale': '3'}},
#    'value': {0: {'loc': '8.999877', 'scale': '-1.5077717'},
#     1: {'loc': '8.999877', 'scale': '-1.5077717'}}},
#   'I_bar': {'prior': {0: {'loc': '9', 'scale': '3'},
#     1: {'loc': '9', 'scale': '3'}},
#    'value': {0: {'loc': '8.999877', 'scale': '-1.5077717'},
#     1: {'loc': '8.999877', 'scale': '-1.5077717'}}},
#   'D': {'prior': {0: {'loc': '9', 'scale': '3'},
#     1: {'loc': '9', 'scale': '3'}},
#    'value': {0: {'loc': '8.999877', 'scale': '-1.5077717'},
#     1: {'loc': '8.999877', 'scale': '-1.5077717'}}},
#   'D_bar': {'prior': {0: {'loc': '9', 'scale': '3'},
#     1: {'loc': '9', 'scale': '3'}},
#    'value': {0: {'loc': '8.999877', 'scale': '-1.5077717'},
#     1: {'loc': '8.999877', 'scale': '-1.5077717'}}},
#   'mean_transform': 'softplus'},
#  'warmup': {'A': {'prior': {0: {'slope': '0',
#      'intercept': '850',
#      'scale': '85'},
#     1: {'slope': '0', 'intercept': '380', 'scale': '38'}},
#    'value': {0: {'slope': '0', 'intercept': '8.499797', 'scale': '0.29240614'},
#     1: {'slope': '0', 'intercept': '3.7773752', 'scale': '-0.7715746'}}},
#   'M': {'prior': {0: {'slope': '0', 'intercept': '650', 'scale': '65'},
#     1: {'slope': '0', 'intercept': '300', 'scale': '30'}},
#    'value': {0: {'slope': '0',
#      'intercept': '6.4984956',
#      'scale': '-0.088240385'},
#     1: {'slope': '0', 'intercept': '2.9489307', 'scale': '-1.0502255'}}},
#   'G': {'prior': {0: {'slope': '0', 'intercept': '30', 'scale': '10'},
#     1: {'slope': '0', 'intercept': '10', 'scale': '5'}},
#    'value': {0: {'slope': '0',
#      'intercept': '-1.0502255',
#      'scale': '-2.2521684'},
#     1: {'slope': '0', 'intercept': '-2.2521684', 'scale': '-2.970628'}}},
#   'GR': {'prior': {0: {'slope': '0', 'intercept': '20', 'scale': '10'},
#     1: {'slope': '0', 'intercept': '10', 'scale': '5'}},
#    'value': {0: {'slope': '0',
#      'intercept': '-1.5077717',
#      'scale': '-2.2521684'},
#     1: {'slope': '0', 'intercept': '-2.2521684', 'scale': '-2.970628'}}},
#   'I': {'prior': {0: {'slope': '0', 'intercept': '10', 'scale': '5'},
#     1: {'slope': '0', 'intercept': '5', 'scale': '3'}},
#    'value': {0: {'slope': '0',
#      'intercept': '-2.2521684',
#      'scale': '-2.970628'},
#     1: {'slope': '0', 'intercept': '-2.970628', 'scale': '-3.4915204'}}},
#   'IR': {'prior': {0: {'slope': '0', 'intercept': '5', 'scale': '5'},
#     1: {'slope': '0', 'intercept': '3', 'scale': '2'}},
#    'value': {0: {'slope': '0', 'intercept': '-2.970628', 'scale': '-2.970628'},
#     1: {'slope': '0', 'intercept': '-3.4915204', 'scale': '-3.9020064'}}},
#   'mean_transform': 'scale_100_softplus'},
#  'init_count': {'G': {'prior': {0: {'loc': '320', 'scale': '32'},
#     1: {'loc': '180', 'scale': '18'}},
#    'value': {0: {'loc': '3.1583838', 'scale': '-0.97517127'},
#     1: {'loc': '1.6193184', 'scale': '-1.6234488'}}},
#   'I': {'prior': {0: {'loc': '140', 'scale': '20'},
#     1: {'loc': '10', 'scale': '5'}},
#    'value': {0: {'loc': '1.116845', 'scale': '-1.5077717'},
#     1: {'loc': '-2.2521684', 'scale': '-2.970628'}}},
#   'mean_transform': 'scale_100_softplus'}}

# %%
with open(new_config_path, 'w') as f:
    json.dump(new_config_json, f, indent = 4)

# %%
json.dumps(json.loads(json.dumps(new_config_json), parse_float=lambda x: round(float(x), 10)))
# Out:
# '{"T_serial": {"prior": {"loc": "5.8", "scale": "1"}, "value": {"loc": "5.2949963", "scale": "0.54132485"}, "mean_transform": "softplus"}, "delta": {"prior": {"a": "1", "b": "1"}, "value": {"loc": "-3.4760988", "scale": "-1.3862944"}, "mean_transform": "sigmoid"}, "epsilon": {"prior": {"a": "1", "b": "1"}, "value": {"loc": "-1.3862944", "scale": "-0.84729785"}, "mean_transform": "sigmoid"}, "rho": {"M": {"prior": {"0": {"a": "4.5", "b": "3.1"}}, "value": {"0": {"loc": "-0.6190392", "scale": "-2.1972246"}}}, "G": {"prior": {"0": {"a": "1.1", "b": "9.6"}}, "value": {"0": {"loc": "-1.9924302", "scale": "-2.1972246"}}}, "I": {"prior": {"0": {"a": "1.1", "b": "9.6"}}, "value": {"0": {"loc": "-1.9924302", "scale": "-2.1972246"}}}, "D": {"prior": {"0": {"a": "1.1", "b": "9.6"}}, "value": {"0": {"loc": "-1.9924302", "scale": "-2.1972246"}}}, "mean_transform": "sigmoid"}, "eff": {"M": {"prior": {"1": {"a": "1", "b": "1"}}, "value": {"1": {"loc": "0.0", "scale": "-2.1972246"}}}, "G": {"prior": {"1": {"a": "1", "b": "1"}}, "value": {"1": {"loc": "0.0", "scale": "-2.1972246"}}}, "I": {"prior": {"1": {"a": "1", "b": "1"}}, "value": {"1": {"loc": "0.0", "scale": "-2.1972246"}}}, "D": {"prior": {"1": {"a": "1", "b": "1"}}, "value": {"1": {"loc": "0.0", "scale": "-2.1972246"}}}, "mean_transform": "sigmoid"}, "lambda": {"M": {"prior": {"0": {"loc": "4.7", "scale": "1"}, "1": {"loc": "4.7", "scale": "1"}}, "value": {"0": {"loc": "2.9489307", "scale": "0.54132485"}, "1": {"loc": "2.9489307", "scale": "0.54132485"}}}, "G": {"prior": {"0": {"loc": "3.3", "scale": "1"}, "1": {"loc": "3.3", "scale": "1"}}, "value": {"0": {"loc": "3.2624195", "scale": "0.54132485"}, "1": {"loc": "3.2624195", "scale": "0.54132485"}}}, "I": {"prior": {"0": {"loc": "3.3", "scale": "1"}, "1": {"loc": "3.3", "scale": "1"}}, "value": {"0": {"loc": "3.2624195", "scale": "0.54132485"}, "1": {"loc": "3.2624195", "scale": "0.54132485"}}}, "I_bar": {"prior": {"0": {"loc": "3.3", "scale": "1"}, "1": {"loc": "3.3", "scale": "1"}}, "value": {"0": {"loc": "3.2624195", "scale": "0.54132485"}, "1": {"loc": "3.2624195", "scale": "0.54132485"}}}, "D": {"prior": {"0": {"loc": "3.3", "scale": "1"}, "1": {"loc": "3.3", "scale": "1"}}, "value": {"0": {"loc": "3.2624195", "scale": "0.54132485"}, "1": {"loc": "3.2624195", "scale": "0.54132485"}}}, "D_bar": {"prior": {"0": {"loc": "3.3", "scale": "1"}, "1": {"loc": "3.3", "scale": "1"}}, "value": {"0": {"loc": "3.2624195", "scale": "0.54132485"}, "1": {"loc": "3.2624195", "scale": "0.54132485"}}}, "mean_transform": "softplus"}, "nu": {"M": {"prior": {"0": {"loc": "3.1", "scale": "1.2"}, "1": {"loc": "3.1", "scale": "1.2"}}, "value": {"0": {"loc": "4.9932394", "scale": "0.8416177"}, "1": {"loc": "4.9932394", "scale": "0.8416177"}}}, "G": {"prior": {"0": {"loc": "9", "scale": "3"}, "1": {"loc": "9", "scale": "3"}}, "value": {"0": {"loc": "8.999877", "scale": "-1.5077717"}, "1": {"loc": "8.999877", "scale": "-1.5077717"}}}, "I": {"prior": {"0": {"loc": "9", "scale": "3"}, "1": {"loc": "9", "scale": "3"}}, "value": {"0": {"loc": "8.999877", "scale": "-1.5077717"}, "1": {"loc": "8.999877", "scale": "-1.5077717"}}}, "I_bar": {"prior": {"0": {"loc": "9", "scale": "3"}, "1": {"loc": "9", "scale": "3"}}, "value": {"0": {"loc": "8.999877", "scale": "-1.5077717"}, "1": {"loc": "8.999877", "scale": "-1.5077717"}}}, "D": {"prior": {"0": {"loc": "9", "scale": "3"}, "1": {"loc": "9", "scale": "3"}}, "value": {"0": {"loc": "8.999877", "scale": "-1.5077717"}, "1": {"loc": "8.999877", "scale": "-1.5077717"}}}, "D_bar": {"prior": {"0": {"loc": "9", "scale": "3"}, "1": {"loc": "9", "scale": "3"}}, "value": {"0": {"loc": "8.999877", "scale": "-1.5077717"}, "1": {"loc": "8.999877", "scale": "-1.5077717"}}}, "mean_transform": "softplus"}, "warmup": {"A": {"prior": {"0": {"slope": "0", "intercept": "850", "scale": "85"}, "1": {"slope": "0", "intercept": "380", "scale": "38"}}, "value": {"0": {"slope": "0", "intercept": "8.499797", "scale": "0.29240614"}, "1": {"slop ...
